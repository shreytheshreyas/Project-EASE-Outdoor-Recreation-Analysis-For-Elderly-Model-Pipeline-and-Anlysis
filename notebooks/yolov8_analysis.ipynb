# %% [markdown]
# #### Importing Necessary Libraries

# %%
import torchvision
import torch 
import time

# %% [markdown]
# #### Pulling necessary directories and from boxmot repo - DO NOT RUN AGAIN

# %%
# !git clone https://github.com/mikel-brostrom/yolo_tracking.git
# %cd yolo_tracking
# !pip install -v -e .
# Out:
# fatal: destination path 'yolo_tracking' already exists and is not an empty directory.
# /Users/shreyaskumar/Documents/Shreyas/Work/yolo_v_8_testing/yolo_tracking
# Using pip 24.0 from /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pip (python 3.10)
# Obtaining file:///Users/shreyaskumar/Documents/Shreyas/Work/yolo_v_8_testing/yolo_tracking
#   Running command python setup.py egg_info
#   running egg_info
#   writing /private/var/folders/2x/68c6g8fs0kb5_l3hvkrcbpb80000gn/T/pip-pip-egg-info-9xt5pt0q/boxmot.egg-info/PKG-INFO
#   writing dependency_links to /private/var/folders/2x/68c6g8fs0kb5_l3hvkrcbpb80000gn/T/pip-pip-egg-info-9xt5pt0q/boxmot.egg-info/dependency_links.txt
#   writing requirements to /private/var/folders/2x/68c6g8fs0kb5_l3hvkrcbpb80000gn/T/pip-pip-egg-info-9xt5pt0q/boxmot.egg-info/requires.txt
#   writing top-level names to /private/var/folders/2x/68c6g8fs0kb5_l3hvkrcbpb80000gn/T/pip-pip-egg-info-9xt5pt0q/boxmot.egg-info/top_level.txt
# ...

# %%
import os
os.getcwd()
# Out:
# '/Users/shreyaskumar/Documents/Shreyas/Work/yolo_v_8_testing/yolo_tracking'

# %%
# %cd yolo_tracking 
# !pip install -v -e .
#!conda install python=3.11 -y -y
#!conda install -c pytorch pytorch -y
# Out:
# [Errno 2] No such file or directory: 'yolo_tracking'
# /Users/shreyaskumar/Documents/Shreyas/Work/yolo_v_8_testing/yolo_tracking
# Using pip 24.0 from /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pip (python 3.10)
# Obtaining file:///Users/shreyaskumar/Documents/Shreyas/Work/yolo_v_8_testing/yolo_tracking
#   Running command python setup.py egg_info
#   running egg_info
#   writing /private/var/folders/2x/68c6g8fs0kb5_l3hvkrcbpb80000gn/T/pip-pip-egg-info-tizy2u3k/boxmot.egg-info/PKG-INFO
#   writing dependency_links to /private/var/folders/2x/68c6g8fs0kb5_l3hvkrcbpb80000gn/T/pip-pip-egg-info-tizy2u3k/boxmot.egg-info/dependency_links.txt
#   writing requirements to /private/var/folders/2x/68c6g8fs0kb5_l3hvkrcbpb80000gn/T/pip-pip-egg-info-tizy2u3k/boxmot.egg-info/requires.txt
#   writing top-level names to /private/var/folders/2x/68c6g8fs0kb5_l3hvkrcbpb80000gn/T/pip-pip-egg-info-tizy2u3k/boxmot.egg-info/top_level.txt
# ...

# %%
# !pip install boxmot

# %% [markdown]
# ### Output format present in files = frame_id, object_id, bounding_box_left, bounding_box_top, bounding_box_width, bounding_box_height, x, y, z

# %% [markdown]
# ##### Output Labels for COCO128 dataset

# %%
names =  ['person', 'bicycle', 'car', 'motorcycle', 'airplane', 'bus', 'train', 'truck', 'boat', 'traffic light',
        'fire hydrant', 'stop sign', 'parking meter', 'bench', 'bird', 'cat', 'dog', 'horse', 'sheep', 'cow',
        'elephant', 'bear', 'zebra', 'giraffe', 'backpack', 'umbrella', 'handbag', 'tie', 'suitcase', 'frisbee',
        'skis', 'snowboard', 'sports ball', 'kite', 'baseball bat', 'baseball glove', 'skateboard', 'surfboard',
        'tennis racket', 'bottle', 'wine glass', 'cup', 'fork', 'knife', 'spoon', 'bowl', 'banana', 'apple',
        'sandwich', 'orange', 'broccoli', 'carrot', 'hot dog', 'pizza', 'donut', 'cake', 'chair', 'couch',
        'potted plant', 'bed', 'dining table', 'toilet', 'tv', 'laptop', 'mouse', 'remote', 'keyboard', 'cell phone',
        'microwave', 'oven', 'toaster', 'sink', 'refrigerator', 'book', 'clock', 'vase', 'scissors', 'teddy bear',
        'hair drier', 'toothbrush'] 

for idx, name in enumerate(names):
    print(f'{idx}: {name}')
# Out:
# 0: person
# 1: bicycle
# 2: car
# 3: motorcycle
# 4: airplane
# 5: bus
# 6: train
# 7: truck
# 8: boat
# 9: traffic light
# 10: fire hydrant
# 11: stop sign
# 12: parking meter
# 13: bench
# 14: bird
# 15: cat
# 16: dog
# 17: horse
# 18: sheep
# 19: cow
# 20: elephant
# 21: bear
# 22: zebra
# 23: giraffe
# 24: backpack
# 25: umbrella
# 26: handbag
# 27: tie
# 28: suitcase
# 29: frisbee
# 30: skis
# 31: snowboard
# 32: sports ball
# 33: kite
# 34: baseball bat
# 35: baseball glove
# 36: skateboard
# 37: surfboard
# 38: tennis racket
# 39: bottle
# 40: wine glass
# 41: cup
# 42: fork
# 43: knife
# 44: spoon
# 45: bowl
# 46: banana
# 47: apple
# 48: sandwich
# 49: orange
# 50: broccoli
# 51: carrot
# 52: hot dog
# 53: pizza
# 54: donut
# 55: cake
# 56: chair
# 57: couch
# 58: potted plant
# 59: bed
# 60: dining table
# 61: toilet
# 62: tv
# 63: laptop
# 64: mouse
# 65: remote
# 66: keyboard
# 67: cell phone
# 68: microwave
# 69: oven
# 70: toaster
# 71: sink
# 72: refrigerator
# ...

# %%
import os
from os.path import isfile 
isfile('/Users/shreyaskumar/Documents/Shreyas/Work/yolo_v_8_testing/yolo_tracking//examples/track.py')
# os.getcwd()
# import cv2
# import numpy as np
 
# # Create a VideoCapture object and read from input file
# # If the input is the camera, pass 0 instead of the video file name
# cap = cv2.VideoCapture('/Users/shreyaskumar/Documents/Shreyas/Work/yolo_v_8_testing/footage/Hiv00001.mp4')
 
# # Check if camera opened successfully
# if (cap.isOpened()== False): 
#   print("Error opening video stream or file")
 
# # Read until video is completed
# while(cap.isOpened()):
#   # Capture frame-by-frame
#   ret, frame = cap.read()
#   if ret == True:
 
#     # Display the resulting frame
#     cv2.imshow('Frame',frame)
 
#     # Press Q on keyboard to  exit
#     if cv2.waitKey(25) & 0xFF == ord('q'):
#       break
 
#   # Break the loop
#   else: 
#     break
 
# # When everything done, release the video capture object
# cap.release()
 
# # Closes all the frames
# cv2.destroyAllWindows()
# Out:
# True

# %%
start_time = time.time()
# !python examples/track.py --yolo-model yolov8s --show --save-mot --source='/Users/shreyaskumar/Documents/Shreyas/Work/yolo_v_8_testing/footage/Hiv00001.mp4' --save --vid_stride 10 # bboxes only
# !python examples/track.py --yolo-model yolov8s --show --save-mot --source='../footage/tampines_sample_2.mp4' # bboxes only
end_time = time.time()
# Out:
# zsh:1: command not found: python

# %%
print(f'Excution Time for baseline BoxMot Model: {end_time-start_time}')
# Out:
# Excution Time for baseline BoxMot Model: 0.12120294570922852

# %%
start_time = time.time()
# !python examples/track.py --yolo-model yolov8n-pose --save-mot --show --source='/Users/shreyaskumar/Documents/Shreyas/Work/yolo_v_8_testing/footage/Hiv00001.mp4' --vid_stride 5 # bboxes and pose keypoints only
end_time = time.time()
# Out:
# zsh:1: command not found: python

# %%
print(f'Excution Time for baseline BoxMot Model: {end_time-start_time}')
# Out:
# Excution Time for baseline BoxMot Model: 0.12477993965148926

# %%
from os import listdir
from os.path import isfile, join

file_directory = '/Users/shreyaskumar/Documents/Shreyas/Work/yolo_v_8_testing/footage/ease_footage/round_market_and_food_court/'
onlyfiles = [join(file_directory, f) for f in listdir(file_directory) if isfile(join(file_directory, f))]
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[12], line 5
#       2 from os.path import isfile, join
#       4 file_directory = '/Users/shreyaskumar/Documents/Shreyas/Work/yolo_v_8_testing/footage/ease_footage/round_market_and_food_court/'
# ----> 5 onlyfiles = [join(file_directory, f) for f in listdir(file_directory) if isfile(join(file_directory, f))]
#
# FileNotFoundError: [Errno 2] No such file or directory: '/Users/shreyaskumar/Documents/Shreyas/Work/yolo_v_8_testing/footage/ease_footage/round_market_and_food_court/'

# %%
onlyfiles.sort()
onlyfiles

# %% [markdown]
# ### YOLOv8 Segmentation model

# %%
start_time = time.time()
# !python examples/track.py --yolo-model yolov8n-seg --show --save-mot --source='../footage/tampines_sample.mp4' --vid_stride 5 # bboxes only
end_time = time.time()

# %% [markdown]
# ### Model Performance Experiment Results for Sequential Processes
# #### Linear Excution of Models:
# * Footage-Duration: 3 minutes 16 seonds = 196 seconds
# * Baseline Model Preditction: 80.17 seconds
# * Pose-estimation model prediction: 95.47 seconds
# * Total Linear Excution Time: 175.64 seconds (Basically almost as long as the video)

# %%
def baseline_mode(filename='../footage/tampines_sample.mp4'):
    # !python examples/track.py --yolo-model yolov8n --save-mot --show --source=filename --vid_stride 5 # bboxes only
    exec(open(f"python ./examples/track.py --yolo-model yolov8n --save-mot --show --source={filename} --vid_stride 5").read())

def pose_estimation_mode(filename='../footage/tampines_sample.mp4'):
    # !python examples/track.py --yolo-model yolov8n-pose --save-mot --show --source=filename --vid_stride 5 # bboxes only
    exec(open(f"python ./examples/track.py --yolo-model yolov8n-pose --save-mot --show --source={filename} --vid_stride 5").read())

# %%
from joblib import Parallel, delayed
import subprocess

start_time = time.time()
subprocess.run('python examples/track.py --yolo-model yolov8n --save-mot --source=\'../footage/tampines_sample.mp4\' --vid_stride 5 & python examples/track.py --yolo-model yolov8n-pose --save-mot --show --source=\'../footage/tampines_sample.mp4\' --vid_stride 5 ' ,shell=True)
end_time = time.time()
# delayed_functions = []
# delayed_functions.append(delayed(baseline_mode)())
# delayed_functions.append(delayed(pose_estimation_mode)())
# Parallel(n_jobs=-1, verbose=5)(delayed_functions)

# %%
print(f'Processing time of model that makes use of subprocess library = {end_time - start_time}')

# %% [markdown]
# ### Model Performance Experiment Results for Sequential Processes
# #### Parallel Excution of Models:
# * Footage-Duration: 3 minutes 16 seonds = 196 seconds
# * Parallel Execution Time: 116.9 seconds
